# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
username = os.getenv('POSTGRES_USERNAME')
password = os.getenv('POSTGRES_PASSWORD')


postgres_connection_string = "postgres://{username}:{password}@{host}:{port}/{database}?gssencmode=disable".format(
    username=username,
    password=password,
    host="localhost",
    port="5432",
    database="lahman_baseball"
)

# %%
engine = create_engine(postgres_connection_string)

# %%
people_sql = "SELECT * FROM people;"
salaries_sql = "SELECT * FROM salaries;"
homegames_sql = "SELECT * FROM homegames;"
parks_sql = "SELECT * FROM parks;"
teams_sql = "SELECT * FROM teams;"

# %%
people_df = pd.read_sql(people_sql, con=engine)
salaries_df = pd.read_sql(salaries_sql, con=engine)
homegames_df = pd.read_sql(homegames_sql, con=engine)
parks_df = pd.read_sql(parks_sql, con=engine)
teams_df = pd.read_sql(teams_sql, con=engine)

# %%
salaries_df.loc[salaries_df['yearid'].idxmin()]
# Out:
# yearid           1985
# teamid            ATL
# lgid               NL
# playerid    barkele01
# salary         870000
# Name: 0, dtype: object

# %%
people_df[people_df['namelast'] == 'Ryan']
# Out:
#        playerid  birthyear  birthmonth  birthday birthcountry birthstate  \
# 15021  ryanbj01     1975.0        12.0      28.0          USA         LA
# 15022  ryanbl01     1906.0         1.0       4.0          USA         MA
# 15023  ryanbr01     1982.0         3.0      26.0          USA         CA
# 15024  ryanbu01     1885.0        10.0       6.0          USA         CO
# 15025  ryanco01     1920.0         2.0      27.0          USA         LA
# 15026  ryancy01     1866.0         NaN       NaN      Ireland       None
# 15027  ryandu01     1984.0         9.0       2.0          USA         CA
# 15028  ryanja01     1868.0        11.0      12.0          USA         MA
# 15029  ryanja02     1884.0         9.0      19.0          USA         IL
# 15030  ryanja03     1905.0         5.0       5.0          USA         KS
# 15031  ryanja04     1976.0         1.0      21.0          USA         NJ
# 15032  ryanji01     1863.0         2.0      11.0          USA         MA
# 15033  ryanjo01     1853.0        10.0       NaN          USA         PA
# 15034  ryanjo02        NaN         NaN       NaN          USA         MI
# 15037  ryanke01     1968.0        10.0      24.0          USA         RI
# 15038  ryanky01     1991.0         9.0      25.0          USA         FL
# 15039  ryanmi01     1868.0         6.0       7.0          USA         MO
# 15040  ryanmi02     1941.0        11.0      25.0          USA         MA
# 15041  ryanmi03     1977.0         7.0       6.0          USA         PA
# 15042  ryanno01     1947.0         1.0      31.0          USA         TX
# 15043  ryanro01     1898.0         3.0      15.0          USA         MA
# 15044  ryanro02     1973.0         6.0      24.0          USA         MT
#
#            birthcity  deathyear  deathmonth  deathday  ... namelast  \
# 15021   Bossier City        NaN         NaN       NaN  ...     Ryan
# 15022           Lynn     1959.0        11.0      28.0  ...     Ryan
# 15023    Los Angeles        NaN         NaN       NaN  ...     Ryan
# 15024         Denver     1956.0         7.0       9.0  ...     Ryan
# 15025    New Orleans     1996.0         1.0       3.0  ...     Ryan
# 15026    Capperwhite     1917.0         1.0      30.0  ...     Ryan
# 15027         Merced        NaN         NaN       NaN  ...     Ryan
# 15028      Haverhill     1952.0         8.0      21.0  ...     Ryan
# 15029  Lawrenceville     1949.0        10.0      16.0  ...     Ryan
# 15030   West Mineral     1967.0         9.0       2.0  ...     Ryan
# 15031    Long Branch        NaN         NaN       NaN  ...     Ryan
# 15032        Clinton     1923.0        10.0      29.0  ...     Ryan
# 15033   Philadelphia     1902.0         3.0      22.0  ...     Ryan
# 15034     Birmingham        NaN         NaN       NaN  ...     Ryan
# 15037      Pawtucket        NaN         NaN       NaN  ...     Ryan
# 15038     Auburndale        NaN         NaN       NaN  ...     Ryan
# 15039      St. Louis     1935.0         9.0       3.0  ...     Ryan
# 15040      Haverhill        NaN         NaN       NaN  ...     Ryan
# 15041        Indiana        NaN         NaN       NaN  ...     Ryan
# 15042        Refugio        NaN         NaN       NaN  ...     Ryan
# 15043      Worcester     1980.0        12.0      10.0  ...     Ryan
# 15044          Havre        NaN         NaN       NaN  ...     Ryan
#
#                    namegiven weight height  bats throws       debut  \
# 15021          Robert Victor  230.0   78.0     L      L  1999-07-28
# 15022           John Collins  178.0   73.0     R      R  1930-07-13
# 15023           Brendan Wood  190.0   73.0     R      R  2007-06-02
# 15024              John Budd  172.0   69.0     L      R  1912-04-11
# 15025       Cornelius Joseph  175.0   71.0     R      R  1942-04-14
# 15026              Daniel R.  200.0   72.0  None      R  1887-08-08
# 15027         Dusty Mitchell  235.0   76.0     R      R  2008-09-04
# 15028           John Bernard  165.0   70.0     R      R  1889-09-02
# 15029                   Jack  165.0   70.0     L      R  1908-07-02
# 15030           John Francis  185.0   72.0     R      R  1929-06-18
# 15031             Jason Paul  185.0   75.0     B      R  1999-08-24
# 15032               James P.  162.0   69.0     R      L  1885-10-08
# 15033            John Joseph  150.0   67.0  None   None  1873-08-19
# 15034                John A.    NaN    NaN     L      R  1884-06-11
# 15037      Kenneth Frederick  200.0   75.0     R      R  1992-08-31
# 15038                   Kyle  215.0   77.0     L      L  2014-08-30
# 15039        Michael Patrick    NaN    NaN  None   None  1895-07-25
# 15040          Michael James  205.0   74.0     R      R  1964-10-03
# 15041           Michael Sean  182.0   70.0     L      R  2002-09-20
# 15042             Lynn Nolan  170.0   74.0     R      R  1966-09-11
# 15043  Wilfred Patrick Dolan  185.0   72.0     L      R  1919-09-07
# 15044           Robert James  190.0   71.0     L      L  1999-08-20
#
#         finalgame   retroid   bbrefid
# 15021  2009-07-05  ryanb001  ryanb.01
# 15022  1938-07-31  ryanb101  ryanbl01
# 15023  2016-06-14  ryanb002  ryanbr01
# 15024  1913-10-05  ryanb102  ryanbu01
# 15025  1954-04-19  ryanc102  ryanco01
# 15026  1891-05-08  ryanc101  ryancy01
# 15027  2009-09-15  ryand001  ryandu01
# 15028  1913-10-04  ryanj103  ryanja01
# 15029  1911-05-09  ryanj102  ryanja02
# 15030  1929-06-19  ryanj104  ryanja03
# 15031  2000-10-01  ryanj001  ryanja04
# 15032  1903-09-24  ryanj105  ryanji01
# 15033  1877-07-12  ryanj106  ryanjo01
# 15034  1884-08-27  ryanj101  ryanjo02
# 15037  1999-05-15  ryank001  ryanke01
# 15038  2016-10-01  ryank002  ryanky01
# 15039  1895-07-27  ryanm102  ryanmi01
# 15040  1974-09-10  ryanm101  ryanmi02
# 15041  2010-06-14  ryanm001  ryanmi03
# 15042  1993-09-22  ryann001  ryanno01
# 15043  1933-09-17  ryanr101  ryanro01
# 15044  2001-10-07  ryanr001  ryanro02
#
# [22 rows x 24 columns]

# %%
mcgwire_salary = salaries_df[salaries_df['playerid'] == 'mcgwima01']

# %%
bonds_salary = salaries_df[salaries_df['playerid'] == 'bondsba01']

# %%
griffey_salary = salaries_df[salaries_df['playerid'] == 'griffke02']

# %%
nryan_salary = salaries_df[salaries_df['playerid'] == 'ryanno01']

# %%
#teams_df[teams_df['teamid'] == 'BSN']

# %%
#teams_df[teams_df['name'] == 'New York Mets']

# %%
#homegames_df[homegames_df['team'] == 'BRO']

# %% [markdown]
# ## Clean up the connection!

# %%
#engine.dispose()
